# %% [markdown]
# ## Visualization with Iris Dataset

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Dataset

# %%
df = sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
plt.figure(figsize=(9,6))

# %%
plt.scatter(df['sepal_length'], df['sepal_width'], color='red', marker='x')

# %%
sns.lmplot(x='sepal_length', y='sepal_width', data=df)

# %% [markdown]
# In seaborn, the **hue** parameter determines which column in the data frame should be used for colour encoding. Using the official document for lmplotprovided an example for this.
#
# https://seaborn.pydata.org/generated/seaborn.lmplot.html

# %%
sns.lmplot(x='sepal_length', y='sepal_width', data=df, hue='species')

# %%
sns.lmplot(x='petal_length', y='petal_width', data=df, hue='species')

# %%
sns.lmplot(x='sepal_length', y='sepal_width', data=df, row='species')

# %%
sns.lmplot(x='petal_length', y='petal_width', data=df, row='species')

# %%
plt.figure(figsize=(18,12))
sns.regplot(x='sepal_length', y='sepal_width', data=df, color='black', order=1)
sns.regplot(x='sepal_length', y='sepal_width', data=df, color='blue', order=2)
sns.regplot(x='sepal_length', y='sepal_width', data=df, color='green', order=3)
sns.regplot(x='sepal_length', y='sepal_width', data=df, color='red', order=7)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
# Boxplot
sns.boxplot(x='species', y='sepal_length', data=df)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %%
sns.boxplot(x='species', y='sepal_width', data=df)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_width'>

# %%
sns.boxplot(x='species', y='petal_length', data=df)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
sns.boxplot(x='species', y='petal_width', data=df)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_width'>

# %% [markdown]
# ## Pairwise relationship

# %%
sns.pairplot(data=df)

# %%
sns.pairplot(data=df, hue='species')

# %%
# heatmap
sns.heatmap(data=df.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(data=df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(data=df.corr(), annot=True, square=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(data=df.corr(), annot=True, square=True, linecolor='black', linewidths=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Try with a simple classification

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
y = df['species'].values
y
# Out:
# array(['setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
# ...

# %%
x = df.drop('species', 1).values
x
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
xTrain, xTest, yTrain, yTest = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
xTrain, yTrain
# Out:
# (array([[4.6, 3.6, 1. , 0.2],
#         [5.7, 4.4, 1.5, 0.4],
#         [6.7, 3.1, 4.4, 1.4],
#         [4.8, 3.4, 1.6, 0.2],
#         [4.4, 3.2, 1.3, 0.2],
#         [6.3, 2.5, 5. , 1.9],
#         [6.4, 3.2, 4.5, 1.5],
#         [5.2, 3.5, 1.5, 0.2],
#         [5. , 3.6, 1.4, 0.2],
#         [5.2, 4.1, 1.5, 0.1],
#         [5.8, 2.7, 5.1, 1.9],
#         [6. , 3.4, 4.5, 1.6],
#         [6.7, 3.1, 4.7, 1.5],
#         [5.4, 3.9, 1.3, 0.4],
#         [5.4, 3.7, 1.5, 0.2],
#         [5.5, 2.4, 3.7, 1. ],
#         [6.3, 2.8, 5.1, 1.5],
#         [6.4, 3.1, 5.5, 1.8],
#         [6.6, 3. , 4.4, 1.4],
#         [7.2, 3.6, 6.1, 2.5],
#         [5.7, 2.9, 4.2, 1.3],
#         [7.6, 3. , 6.6, 2.1],
#         [5.6, 3. , 4.5, 1.5],
#         [5.1, 3.5, 1.4, 0.2],
#         [7.7, 2.8, 6.7, 2. ],
#         [5.8, 2.7, 4.1, 1. ],
#         [5.2, 3.4, 1.4, 0.2],
#         [5. , 3.5, 1.3, 0.3],
#         [5.1, 3.8, 1.9, 0.4],
#         [5. , 2. , 3.5, 1. ],
#         [6.3, 2.7, 4.9, 1.8],
# ...

# %%
nb = GaussianNB()
nb.fit(xTrain, yTrain)

yPred = nb.predict(xTest)
yPred
# Out:
# array(['versicolor', 'setosa', 'virginica', 'versicolor', 'versicolor',
#        'setosa', 'versicolor', 'virginica', 'versicolor', 'versicolor',
#        'virginica', 'setosa', 'setosa', 'setosa', 'setosa', 'versicolor',
#        'virginica', 'versicolor', 'versicolor', 'virginica', 'setosa',
#        'virginica', 'setosa', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'setosa', 'setosa'], dtype=object)

# %%
confusion_matrix(yTest, yPred)
# Out:
# array([[10,  0,  0],
#        [ 0,  9,  0],
#        [ 0,  0, 11]], dtype=int64)

# %%
classification_report(yTest, yPred)
# Out:
# '              precision    recall  f1-score   support\n\n      setosa       1.00      1.00      1.00        10\n  versicolor       1.00      1.00      1.00         9\n   virginica       1.00      1.00      1.00        11\n\n    accuracy                           1.00        30\n   macro avg       1.00      1.00      1.00        30\nweighted avg       1.00      1.00      1.00        30\n'

# %% [markdown]
# Confusion matrix
#
# https://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html

# %%
newDFHeatMap = pd.DataFrame(confusion_matrix(yTest, yPred), index = np.unique(yTest), columns = np.unique(yPred))
print(newDFHeatMap)
sns.heatmap(data=newDFHeatMap, annot=True, cmap='Blues')
# Out:
#             setosa  versicolor  virginica
# setosa          10           0          0
# versicolor       0           9          0
# virginica        0           0         11
# <AxesSubplot:>

# %%
newDFClassReport = pd.DataFrame(classification_report(yTest, yPred, output_dict=True)).transpose()
print(newDFClassReport)
sns.heatmap(data=newDFClassReport, annot=True, cmap='Blues')
# Out:
#               precision  recall  f1-score  support
# setosa              1.0     1.0       1.0     10.0
# versicolor          1.0     1.0       1.0      9.0
# virginica           1.0     1.0       1.0     11.0
# accuracy            1.0     1.0       1.0      1.0
# macro avg           1.0     1.0       1.0     30.0
# weighted avg        1.0     1.0       1.0     30.0
# <AxesSubplot:>

# %% [markdown]
# ## Additional styling with a new dataset

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
sns.relplot(x='total_bill', y='tip', data=tips, hue='day')

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='day')

# %%
sns.relplot(x='total_bill', y='tip', data=tips, hue='sex')

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex')

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='day', col='time')

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='day', col='time', row='sex')

# %%
sns.jointplot(x='total_bill', y='tip', data=tips)

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, hue='sex')

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='kde')

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='kde', hue='sex')

# %% [markdown]
# ## Color and Styles

# %%
sns.color_palette('deep')
# Out:
# [(0.2980392156862745, 0.4470588235294118, 0.6901960784313725),
#  (0.8666666666666667, 0.5176470588235295, 0.3215686274509804),
#  (0.3333333333333333, 0.6588235294117647, 0.40784313725490196),
#  (0.7686274509803922, 0.3058823529411765, 0.3215686274509804),
#  (0.5058823529411764, 0.4470588235294118, 0.7019607843137254),
#  (0.5764705882352941, 0.47058823529411764, 0.3764705882352941),
#  (0.8549019607843137, 0.5450980392156862, 0.7647058823529411),
#  (0.5490196078431373, 0.5490196078431373, 0.5490196078431373),
#  (0.8, 0.7254901960784313, 0.4549019607843137),
#  (0.39215686274509803, 0.7098039215686275, 0.803921568627451)]

# %%
sns.color_palette('coolwarm')
# Out:
# [(0.4044212904941176, 0.5346434904470588, 0.9320019126352941),
#  (0.603162067917647, 0.7315274773529412, 0.9995652785372549),
#  (0.7867207013568628, 0.8448072103686275, 0.9398103849490196),
#  (0.9306685963333333, 0.818876999654902, 0.7591463906980392),
#  (0.9673165156666667, 0.6574708288078431, 0.5381601507294118),
#  (0.8846434386941177, 0.41001709788235297, 0.32250654924705885)]

# %%
sns.set_palette('deep')
sns.jointplot(x='total_bill', y='tip', data=tips, hue='sex')

# %%
sns.set_palette('coolwarm')
sns.jointplot(x='total_bill', y='tip', data=tips, hue='sex')

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='day', col='time', row='sex')

# %%
sns.set_style('whitegrid')
sns.set_palette('dark')
sns.lmplot(x='total_bill', y='tip', data=tips, hue='day', col='time', row='sex')

# %%
sns.set_style('darkgrid')
sns.set_palette('dark')
sns.lmplot(x='total_bill', y='tip', data=tips, hue='day', col='time', row='sex')

# %%
sns.set_style('whitegrid')
sns.set_palette('Set2')
sns.lmplot(x='total_bill', y='tip', data=tips, hue='day', col='time', row='sex')

# %%
plt.style.use('dark_background')
sns.lmplot(x='total_bill', y='tip', data=tips, hue='day', col='time', row='sex')

# %%
plt.style.use('dark_background')
sns.set_palette('coolwarm')
sns.lmplot(x='total_bill', y='tip', data=tips, hue='day', col='time', row='sex')
